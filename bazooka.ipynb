# %%
from bazooka import Scraper
import pandas as pd

# %%
s = Scraper()
r = s.getResult(540017)
r[0] = r[0].transpose()
r[0] = r[0].rename(columns=r[0].iloc[0]).drop(r[0].index[0])
r[0] = r[0].set_index("رقم الجلوس")
r[1] = r[1].transpose()
r[1] = r[1].rename(columns=r[1].iloc[0]).drop(r[1].index[0]).set_index(r[0].index)
r[2] = r[2].transpose()
r[2] = r[2].rename(columns=r[2].iloc[0]).drop(r[2].index[0]).set_index(r[0].index)
r_f = pd.concat([r[0], r[1], r[2]], axis=1)
# Out:
# /tmp/ipykernel_1862/2809501766.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   r_f.append(r_f)
#                                       الإسم  \
# رقم الجلوس
# 540017      كلارا باسم منصور سلامه الطلياوى
# 540017      كلارا باسم منصور سلامه الطلياوى
#
#                                            المدرسة    المديرية  الإدارة  \
# رقم الجلوس
# 540017      ام المؤمنين الثانويه الرسمية بنات لغات  الاسكندرية  المنتزه
# 540017      ام المؤمنين الثانويه الرسمية بنات لغات  الاسكندرية  المنتزه
#
#                                          اسم اللجنة  \
# رقم الجلوس
# 540017      لجنة النظام والمراقبة قطاع الاسكندرية ب
# 540017      لجنة النظام والمراقبة قطاع الاسكندرية ب
#
#                                                  عنوان اللجنة     الهاتف  \
# رقم الجلوس
# 540017      مدرسة الشاطبى الإعدادية بنين - 6 شارع هومير بج...  034864542
# 540017      مدرسة الشاطبى الإعدادية بنين - 6 شارع هومير بج...  034864542
#
#            اللغة العربية اللغة الأجنبية الأولى اللغة الأجنبية الثانية التاريخ  \
# رقم الجلوس
# 540017                54                    40                     39      30
# 540017                54                    40                     39      30
#
#            الجغرافيا الفلسفة والمنطق علم النفس والإجتماع المجموع الكلى  \
# رقم الجلوس
# 540017            30              39                  45           277
# 540017            30              39                  45           277
#
#            التربية الدينية التربية الوطنية الإقتصاد والإحصاء
# رقم الجلوس
# 540017                  17              22                25
# 540017                  17              22                25

# %%
r = s.getResult(540017)
# Out:
#   البيانات الشخصية                                 البيانات الشخصية.1
# 0       رقم الجلوس                                             540017
# 1            الإسم                    كلارا باسم منصور سلامه الطلياوى
# 2          المدرسة             ام المؤمنين الثانويه الرسمية بنات لغات
# 3         المديرية                                         الاسكندرية
# 4          الإدارة                                            المنتزه
# 5       اسم اللجنة            لجنة النظام والمراقبة قطاع الاسكندرية ب
# 6     عنوان اللجنة  مدرسة الشاطبى الإعدادية بنين - 6 شارع هومير بج...
# 7           الهاتف                                          034864542
